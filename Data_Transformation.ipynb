# %% [markdown]
# <a href="https://colab.research.google.com/github/hadassaholive/hds5210-2023/blob/main/Data_Transformation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('us_state_vaccinations.csv')

# %%
data.columns
# Out:
# Index(['date', 'location', 'total_vaccinations', 'total_distributed',
#        'people_vaccinated', 'people_fully_vaccinated_per_hundred',
#        'total_vaccinations_per_hundred', 'people_fully_vaccinated',
#        'people_vaccinated_per_hundred', 'distributed_per_hundred',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'daily_vaccinations_per_million', 'share_doses_used', 'total_boosters',
#        'total_boosters_per_hundred'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54628 entries, 0 to 54627
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   date                                 54628 non-null  object
#  1   location                             54628 non-null  object
#  2   total_vaccinations                   32532 non-null  float64
#  3   total_distributed                    32272 non-null  float64
#  4   people_vaccinated                    32268 non-null  float64
#  5   people_fully_vaccinated_per_hundred  30651 non-null  float64
#  6   total_vaccinations_per_hundred       30750 non-null  float64
#  7   people_fully_vaccinated              32188 non-null  float64
#  8   people_vaccinated_per_hundred        30726 non-null  float64
#  9   distributed_per_hundred              30730 non-null  float64
#  10  daily_vaccinations_raw               28354 non-null  float64
# ...

# %%
data.shape
# Out:
# (54628, 16)

# %%
data.ndim
# Out:
# 2

# %%
data.head()
# Out:
#          date location  total_vaccinations  total_distributed  \
# 0  2021-01-12  Alabama             78134.0           377025.0
# 1  2021-01-13  Alabama             84040.0           378975.0
# 2  2021-01-14  Alabama             92300.0           435350.0
# 3  2021-01-15  Alabama            100567.0           444650.0
# 4  2021-01-16  Alabama                 NaN                NaN
#
#    people_vaccinated  people_fully_vaccinated_per_hundred  \
# 0            70861.0                                 0.15
# 1            74792.0                                 0.19
# 2            80480.0                                  NaN
# 3            86956.0                                 0.28
# 4                NaN                                  NaN
#
#    total_vaccinations_per_hundred  people_fully_vaccinated  \
# 0                            1.59                   7270.0
# 1                            1.71                   9245.0
# ...

# %%
data.describe()
# Out:
#        total_vaccinations  total_distributed  people_vaccinated  \
# count        3.253200e+04       3.227200e+04       3.226800e+04
# mean         1.185199e+07       1.498832e+07       5.909278e+06
# std          5.198221e+07       6.626668e+07       2.508631e+07
# min          4.160000e+02       6.000000e+03       4.010000e+02
# 25%          9.277308e+05       1.188560e+06       5.043098e+05
# 50%          3.199256e+06       4.051065e+06       1.730820e+06
# 75%          7.948546e+06       1.006490e+07       4.023565e+06
# max          6.767288e+08       9.844443e+08       2.702272e+08
#
#        people_fully_vaccinated_per_hundred  total_vaccinations_per_hundred  \
# count                         30651.000000                    30750.000000
# mean                             47.332224                      114.716897
# std                              22.037456                       57.873521
# min                               0.000000                        0.170000
# ...

# %%
data.drop_duplicates()
# Out:
#              date location  total_vaccinations  total_distributed  \
# 0      2021-01-12  Alabama             78134.0           377025.0
# 1      2021-01-13  Alabama             84040.0           378975.0
# 2      2021-01-14  Alabama             92300.0           435350.0
# 3      2021-01-15  Alabama            100567.0           444650.0
# 4      2021-01-16  Alabama                 NaN                NaN
# ...           ...      ...                 ...                ...
# 54623  2023-05-06  Wyoming                 NaN                NaN
# 54624  2023-05-07  Wyoming                 NaN                NaN
# 54625  2023-05-08  Wyoming                 NaN                NaN
# 54626  2023-05-09  Wyoming                 NaN                NaN
# 54627  2023-05-10  Wyoming            854132.0          1281755.0
#
#        people_vaccinated  people_fully_vaccinated_per_hundred  \
# 0                70861.0                                 0.15
# ...

# %%
data['date'] = data['date'].astype(object)

# %%
data['location'] = data['location'].astype(object)

# %%
data['total_vaccinations'] = data['total_vaccinations'].astype(object)

# %%
data['total_distributed'] = data['total_distributed'].astype(object)

# %%
data['people_vaccinated'] = data['people_vaccinated'].astype(object)

# %%
data['people_fully_vaccinated_per_hundred'] = data['people_fully_vaccinated_per_hundred'].astype(object)

# %%
data['total_vaccinations_per_hundred'] = data['total_vaccinations_per_hundred'].astype(object)

# %%
data['people_fully_vaccinated'] = data['people_fully_vaccinated'].astype(object)

# %%
data['people_vaccinated_per_hundred'] = data['people_vaccinated_per_hundred'].astype(object)

# %%
data['distributed_per_hundred'] = data['distributed_per_hundred'].astype(object)

# %%
data['daily_vaccinations_raw'] = data['daily_vaccinations_raw'].astype(object)

# %%
data['daily_vaccinations'] = data['daily_vaccinations'].astype(object)

# %%
data['daily_vaccinations_per_million'] = data['daily_vaccinations_per_million'].astype(object)

# %%
data['share_doses_used'] = data['share_doses_used'].astype(object)

# %%
data['total_boosters'] = data['total_boosters'].astype(object)

# %%
data['total_boosters_per_hundred'] = data['total_boosters_per_hundred'].astype(object)

# %%
data.dtypes
# Out:
# date                                   object
# location                               object
# total_vaccinations                     object
# total_distributed                      object
# people_vaccinated                      object
# people_fully_vaccinated_per_hundred    object
# total_vaccinations_per_hundred         object
# people_fully_vaccinated                object
# people_vaccinated_per_hundred          object
# distributed_per_hundred                object
# daily_vaccinations_raw                 object
# daily_vaccinations                     object
# daily_vaccinations_per_million         object
# share_doses_used                       object
# total_boosters                         object
# total_boosters_per_hundred             object
# dtype: object

# %%
data = data.replace('NaN','' )

# %%
data.fillna('-', inplace= True)

# %%
data.rename(columns={'location':'state'})
# Out:
#              date    state total_vaccinations total_distributed  \
# 0      2021-01-12  Alabama            78134.0          377025.0
# 1      2021-01-13  Alabama            84040.0          378975.0
# 2      2021-01-14  Alabama            92300.0          435350.0
# 3      2021-01-15  Alabama           100567.0          444650.0
# 4      2021-01-16  Alabama                  -                 -
# ...           ...      ...                ...               ...
# 54623  2023-05-06  Wyoming                  -                 -
# 54624  2023-05-07  Wyoming                  -                 -
# 54625  2023-05-08  Wyoming                  -                 -
# 54626  2023-05-09  Wyoming                  -                 -
# 54627  2023-05-10  Wyoming           854132.0         1281755.0
#
#       people_vaccinated people_fully_vaccinated_per_hundred  \
# 0               70861.0                                0.15
# 1               74792.0                                0.19
# ...

# %%
data = data.drop('daily_vaccinations_raw', axis=1)
